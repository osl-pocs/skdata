# %% [markdown]
#  # Table of Contents
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item" id="toc-level0"><li><span><a href="http://localhost:8888/notebooks/SkData-SciPyLA2017-Propose.ipynb#SkData" data-toc-modified-id="SkData-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>SkData</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/SkData-SciPyLA2017-Propose.ipynb#Motivaciones" data-toc-modified-id="Motivaciones-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Motivaciones</a></span></li><li><span><a href="http://localhost:8888/notebooks/SkData-SciPyLA2017-Propose.ipynb#Inspiraciones" data-toc-modified-id="Inspiraciones-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Inspiraciones</a></span></li><li><span><a href="http://localhost:8888/notebooks/SkData-SciPyLA2017-Propose.ipynb#Objetivos" data-toc-modified-id="Objetivos-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Objetivos</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/SkData-SciPyLA2017-Propose.ipynb#Limpieza-de-datos" data-toc-modified-id="Limpieza-de-datos-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Limpieza de datos</a></span></li><li><span><a href="http://localhost:8888/notebooks/SkData-SciPyLA2017-Propose.ipynb#Reproducibilidad" data-toc-modified-id="Reproducibilidad-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Reproducibilidad</a></span></li><li><span><a href="http://localhost:8888/notebooks/SkData-SciPyLA2017-Propose.ipynb#Visualización-de-datos" data-toc-modified-id="Visualización-de-datos-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Visualización de datos</a></span></li></ul></li><li><span><a href="http://localhost:8888/notebooks/SkData-SciPyLA2017-Propose.ipynb#Aplicación" data-toc-modified-id="Aplicación-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Aplicación</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/SkData-SciPyLA2017-Propose.ipynb#Importing-data" data-toc-modified-id="Importing-data-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Importing data</a></span></li><li><span><a href="http://localhost:8888/notebooks/SkData-SciPyLA2017-Propose.ipynb#Data-preparing-and-cleaning" data-toc-modified-id="Data-preparing-and-cleaning-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Data preparing and cleaning</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # SkData

# %% [markdown]
# SkData es un proyecto nuevo, de 2017, con la finalidad de facilitar el análisis de datos, proviendo funcionalidades como:
#
# - limpieza de datos;
# - reproducibilidad de la manipulación/tratamiento de los datos;
# - visualización de datos;

# %% [markdown]
# ## Motivaciones

# %% [markdown]
# La construcción de la librería fue motivada por:
#
# - exceso de boilerplate en el análisis de datos;
# - el uso de librerías como pandas, matplotlib, scipy, etc pueden ser difícil en un principio para no programadores;
# - en un escenario dónde la demanda es mayor que los recursos (personas, tiempo, etc) tener mecanismo que pueden agilizar en proceso de análisis de datos es fundamental.

# %% [markdown]
# ## Inspiraciones

# %% [markdown]
# SkData se ha inspirado en funcionalidades de otros softwares como:
#
# - weka (http://www.cs.waikato.ac.nz/ml/weka/)
# - openrefine (http://openrefine.org/)
#
# Las visualizaciones gráficas en weka permiten de manera fácil entender
# las relaciones entre los atributos del conjunto de datos. El
# entendimiento previo de estas relaciones ayuda a determinar los pasos
# siguientes en el análisis de datos. Mientras que, generalmente, la
# programación de visualización de datos consume un poco de tiempo,
# tener un medio de hacerlo de manera automática, sin o con muy poco código,
# facilitaría mucho en el análisis de datos.
#
# La limpieza/tratamiento de los datos pueden ser una tarea que consume mucho
# tiempo y, muchas veces, el proceso se repite en el análisis de distintos
# conjunto de datos. A parte de eso, tener el control de los pasos/manipulaciones
# de los datos, puede facilitar el proceso de análisis sin modificar los datos
# originales. OpenRefine provee estos recursos y muchas otras funcionalidades
# para limpieza de datos y otras funcionalidades como reconcilización de datos.

# %% [markdown]
# ## Objetivos

# %% [markdown]
# Como ya mencionado, inicialmente skdata tiene 3 objetivos que serán comentados a continuación.

# %% [markdown]
# ### Limpieza de datos

# %% [markdown]
# ### Reproducibilidad

# %% [markdown]
# ### Visualización de datos

# %% [markdown]
# ## Aplicación

# %% [markdown]
# SkData provide a data class to structure and organize the preprocessing data.
#
# The data is stored in **hdf5** format. The original data is kept and all steps
# of preprocessing is kept to and applied on demand.

# %% [markdown]
# To import data from *csv* source:
#
# ```python
# from skdata import SkData
#
# sd = SkData('filename.h5')
# sd.import_from(source='filename.csv')
# ```

# %%
from skdata import SkData

# %% [markdown]
# ### Importing data

# %%
sd = SkData('/tmp/titanic.h5')

sd.import_from(
    source='../data/train.csv', 
    index_col='PassengerId',
    target_col='Survived',
    dset_id='train'
)

# %%
sd['train'].summary(compute=True)
# Out:
#             Types                                         Set Values  \
# Survived    int64                                             [0, 1]
# Pclass      int64                                          [1, 2, 3]
# Name       object  ['Abbing, Mr. Anthony', 'Abbott, Mr. Rossmore ...
# Sex        object                                 ['female', 'male']
# Age       float64  [0.42, 0.67, 0.75, 0.83, 0.92, 1.0, 2.0, 3.0, ...
# SibSp       int64                              [0, 1, 2, 3, 4, 5, 8]
# Parch       int64                              [0, 1, 2, 3, 4, 5, 6]
# Ticket     object  ['110152', '110413', '110465', '110564', '1108...
# Fare      float64  [0.0, 4.0125, 5.0, 6.2375, 6.4375, 6.45, 6.495...
# Cabin      object  ['A10', 'A14', 'A16', 'A19', 'A20', 'A23', 'A2...
# Embarked   object                                    ['C', 'Q', 'S']
#
#           Count Set  # Observations  # NaN
# Survived          2             891      0
# Pclass            3             891      0
# ...

# %%
sd['train'].computed.head()
# Out:
#    Survived  Pclass                                               Name  \
# 1         0       3                            Braund, Mr. Owen Harris
# 2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1       3                             Heikkinen, Miss. Laina
# 4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 1    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  female  38.0      1      0          PC 17599  71.2833   C85        C
# 3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4  female  35.0      1      0            113803  53.1000  C123        S
# 5    male  35.0      0      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Data preparing and cleaning

# %%
sd['train']['Sex'].replace({'male': 'Male', 'female': 'Female'})
sd['train']['Embarked'].replace({
    'C': 'Cherbourg', 'Q': 'Queenstown', 'S': 'Southampton'
})

sd['train'].compute()
sd['train'].computed.head()
# Out:
#    Survived  Pclass                                               Name  \
# 1         0       3                            Braund, Mr. Owen Harris
# 2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1       3                             Heikkinen, Miss. Laina
# 4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin     Embarked
# 1    Male  22.0      1      0         A/5 21171   7.2500   NaN  Southampton
# 2  Female  38.0      1      0          PC 17599  71.2833   C85    Cherbourg
# 3  Female  26.0      0      0  STON/O2. 3101282   7.9250   NaN  Southampton
# 4  Female  35.0      1      0            113803  53.1000  C123  Southampton
# 5    Male  35.0      0      0            373450   8.0500   NaN  Southampton

# %%
survived_dict = {0: 'Died', 1: 'Survived'}
pclass_dict = {1: 'Upper Class', 2: 'Middle Class', 3: 'Lower Class'}

sd['train']['Pclass'].categorize(categories=pclass_dict)
sd['train']['Survived'].categorize(categories=survived_dict)
sd['train']['Sex'].categorize()
sd['train']['Embarked'].categorize()

sd['train'].summary(compute=True)
# Out:
#              Types                                         Set Values  \
# Survived  category                               ['Died', 'Survived']
# Pclass    category     ['Lower Class', 'Middle Class', 'Upper Class']
# Name        object  ['Abbing, Mr. Anthony', 'Abbott, Mr. Rossmore ...
# Sex       category                                 ['Female', 'Male']
# Age        float64  [0.42, 0.67, 0.75, 0.83, 0.92, 1.0, 2.0, 3.0, ...
# SibSp        int64                              [0, 1, 2, 3, 4, 5, 8]
# Parch        int64                              [0, 1, 2, 3, 4, 5, 6]
# Ticket      object  ['110152', '110413', '110465', '110564', '1108...
# Fare       float64  [0.0, 4.0125, 5.0, 6.2375, 6.4375, 6.45, 6.495...
# Cabin       object  ['A10', 'A14', 'A16', 'A19', 'A20', 'A23', 'A2...
# Embarked  category         ['Cherbourg', 'Queenstown', 'Southampton']
#
#           Count Set  # Observations  # NaN
# Survived          2             891      0
# ...

# %%
sd['train'].computed.head()
# Out:
#    Survived       Pclass                                               Name  \
# 1      Died  Lower Class                            Braund, Mr. Owen Harris
# 2  Survived  Upper Class  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3  Survived  Lower Class                             Heikkinen, Miss. Laina
# 4  Survived  Upper Class       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5      Died  Lower Class                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin     Embarked
# 1    Male  22.0      1      0         A/5 21171   7.2500   NaN  Southampton
# 2  Female  38.0      1      0          PC 17599  71.2833   C85    Cherbourg
# 3  Female  26.0      0      0  STON/O2. 3101282   7.9250   NaN  Southampton
# 4  Female  35.0      1      0            113803  53.1000  C123  Southampton
# 5    Male  35.0      0      0            373450   8.0500   NaN  Southampton

# %%
sd['train'].drop_columns(max_na_values=0.1)
sd['train'].summary(compute=True)
# Out:
#              Types                                         Set Values  \
# Survived  category                               ['Died', 'Survived']
# Pclass    category     ['Lower Class', 'Middle Class', 'Upper Class']
# Name        object  ['Abbing, Mr. Anthony', 'Abbott, Mr. Rossmore ...
# Sex       category                                 ['Female', 'Male']
# SibSp        int64                              [0, 1, 2, 3, 4, 5, 8]
# Parch        int64                              [0, 1, 2, 3, 4, 5, 6]
# Ticket      object  ['110152', '110413', '110465', '110564', '1108...
# Fare       float64  [0.0, 4.0125, 5.0, 6.2375, 6.4375, 6.45, 6.495...
# Embarked  category         ['Cherbourg', 'Queenstown', 'Southampton']
#
#           Count Set  # Observations  # NaN
# Survived          2             891      0
# Pclass            3             891      0
# Name            891             891      0
# Sex               2             891      0
# SibSp             7             891      0
# ...

# %%
sd['train'].dropna()
sd['train'].summary(compute=True)
# Out:
#              Types                                         Set Values  \
# Survived  category                               ['Died', 'Survived']
# Pclass    category     ['Lower Class', 'Middle Class', 'Upper Class']
# Name        object  ['Abbing, Mr. Anthony', 'Abbott, Mr. Rossmore ...
# Sex       category                                 ['Female', 'Male']
# SibSp        int64                              [0, 1, 2, 3, 4, 5, 8]
# Parch        int64                              [0, 1, 2, 3, 4, 5, 6]
# Ticket      object  ['110152', '110413', '110465', '110564', '1108...
# Fare       float64  [0.0, 4.0125, 5.0, 6.2375, 6.4375, 6.45, 6.495...
# Embarked  category         ['Cherbourg', 'Queenstown', 'Southampton']
#
#           Count Set  # Observations  # NaN
# Survived          2             889      0
# Pclass            3             889      0
# Name            889             889      0
# Sex               2             889      0
# SibSp             7             889      0
# ...

# %%
sd['train'].drop_columns(max_unique_values=0.3)
sd['train'].summary(compute=True)
# Out:
#              Types                                         Set Values  \
# Survived  category                               ['Died', 'Survived']
# Pclass    category     ['Lower Class', 'Middle Class', 'Upper Class']
# Sex       category                                 ['Female', 'Male']
# SibSp        int64                              [0, 1, 2, 3, 4, 5, 8]
# Parch        int64                              [0, 1, 2, 3, 4, 5, 6]
# Fare       float64  [0.0, 4.0125, 5.0, 6.2375, 6.4375, 6.45, 6.495...
# Embarked  category         ['Cherbourg', 'Queenstown', 'Southampton']
#
#           Count Set  # Observations  # NaN
# Survived          2             889      0
# Pclass            3             889      0
# Sex               2             889      0
# SibSp             7             889      0
# Parch             7             889      0
# Fare            247             889      0
# Embarked          3             889      0
